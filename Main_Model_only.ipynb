# %%
pip install pycaret
# Out:
# Requirement already satisfied: pycaret in ./env/lib/python3.8/site-packages (3.1.0)
# Requirement already satisfied: wurlitzer; platform_system != "Windows" in ./env/lib/python3.8/site-packages (from pycaret) (3.0.3)
# Requirement already satisfied: numpy<1.24,>=1.21 in ./env/lib/python3.8/site-packages (from pycaret) (1.23.5)
# Requirement already satisfied: sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1 in ./env/lib/python3.8/site-packages (from pycaret) (0.21.1)
# Requirement already satisfied: schemdraw==0.15 in ./env/lib/python3.8/site-packages (from pycaret) (0.15)
# Requirement already satisfied: matplotlib>=3.3.0 in ./env/lib/python3.8/site-packages (from pycaret) (3.7.3)
# Requirement already satisfied: tqdm>=4.62.0 in ./env/lib/python3.8/site-packages (from pycaret) (4.66.1)
# Requirement already satisfied: kaleido>=0.2.1 in ./env/lib/python3.8/site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in ./env/lib/python3.8/site-packages (from pycaret) (0.9.1)
# Requirement already satisfied: category-encoders>=2.4.0 in ./env/lib/python3.8/site-packages (from pycaret) (2.6.2)
# Requirement already satisfied: xxhash in ./env/lib/python3.8/site-packages (from pycaret) (3.3.0)
# Requirement already satisfied: nbformat>=4.2.0 in ./env/lib/python3.8/site-packages (from pycaret) (5.9.2)
# Requirement already satisfied: requests>=2.27.1 in ./env/lib/python3.8/site-packages (from pycaret) (2.31.0)
# Requirement already satisfied: markupsafe>=2.0.1 in ./env/lib/python3.8/site-packages (from pycaret) (2.1.3)
# Requirement already satisfied: yellowbrick>=1.4 in ./env/lib/python3.8/site-packages (from pycaret) (1.5)
# Requirement already satisfied: lightgbm>=3.0.0 in ./env/lib/python3.8/site-packages (from pycaret) (4.1.0)
# Requirement already satisfied: pyod>=1.0.8 in ./env/lib/python3.8/site-packages (from pycaret) (1.1.0)
# Requirement already satisfied: numba>=0.55.0 in ./env/lib/python3.8/site-packages (from pycaret) (0.57.1)
# Requirement already satisfied: scikit-plot>=0.3.7 in ./env/lib/python3.8/site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: ipython>=5.5.0 in ./env/lib/python3.8/site-packages (from pycaret) (8.12.2)
# Requirement already satisfied: joblib>=1.2.0 in ./env/lib/python3.8/site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in ./env/lib/python3.8/site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: statsmodels>=0.12.1 in ./env/lib/python3.8/site-packages (from pycaret) (0.14.0)
# Requirement already satisfied: tbats>=1.1.3 in ./env/lib/python3.8/site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: cloudpickle in ./env/lib/python3.8/site-packages (from pycaret) (2.2.1)
# Requirement already satisfied: deprecation>=2.1.0 in ./env/lib/python3.8/site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: psutil>=5.9.0 in ./env/lib/python3.8/site-packages (from pycaret) (5.9.5)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in ./env/lib/python3.8/site-packages (from pycaret) (1.5.3)
# Requirement already satisfied: jinja2>=1.2 in ./env/lib/python3.8/site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: plotly>=5.0.0 in ./env/lib/python3.8/site-packages (from pycaret) (5.17.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in ./env/lib/python3.8/site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: importlib-metadata>=4.12.0 in ./env/lib/python3.8/site-packages (from pycaret) (6.8.0)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in ./env/lib/python3.8/site-packages (from pycaret) (1.2.2)
# Requirement already satisfied: ipywidgets>=7.6.5 in ./env/lib/python3.8/site-packages (from pycaret) (8.1.1)
# Requirement already satisfied: scipy~=1.10.1 in ./env/lib/python3.8/site-packages (from pycaret) (1.10.1)
# Requirement already satisfied: deprecated>=1.2.13 in ./env/lib/python3.8/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.2.14)
# Requirement already satisfied: scikit-base<0.6.0 in ./env/lib/python3.8/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (0.5.1)
# Requirement already satisfied: packaging in ./env/lib/python3.8/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (23.1)
# Requirement already satisfied: cycler>=0.10 in ./env/lib/python3.8/site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./env/lib/python3.8/site-packages (from matplotlib>=3.3.0->pycaret) (1.1.0)
# Requirement already satisfied: pillow>=6.2.0 in ./env/lib/python3.8/site-packages (from matplotlib>=3.3.0->pycaret) (10.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./env/lib/python3.8/site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in ./env/lib/python3.8/site-packages (from matplotlib>=3.3.0->pycaret) (6.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./env/lib/python3.8/site-packages (from matplotlib>=3.3.0->pycaret) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in ./env/lib/python3.8/site-packages (from matplotlib>=3.3.0->pycaret) (4.42.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./env/lib/python3.8/site-packages (from matplotlib>=3.3.0->pycaret) (3.1.1)
# Requirement already satisfied: tsdownsample==0.1.2 in ./env/lib/python3.8/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in ./env/lib/python3.8/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.9.7)
# Requirement already satisfied: dash<3.0.0,>=2.11.0 in ./env/lib/python3.8/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.13.0)
# Requirement already satisfied: trace-updater>=0.0.8 in ./env/lib/python3.8/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.0.9.1)
# Requirement already satisfied: patsy>=0.5.1 in ./env/lib/python3.8/site-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: traitlets>=5.1 in ./env/lib/python3.8/site-packages (from nbformat>=4.2.0->pycaret) (5.10.0)
# Requirement already satisfied: jsonschema>=2.6 in ./env/lib/python3.8/site-packages (from nbformat>=4.2.0->pycaret) (4.19.0)
# Requirement already satisfied: fastjsonschema in ./env/lib/python3.8/site-packages (from nbformat>=4.2.0->pycaret) (2.18.0)
# Requirement already satisfied: jupyter-core in ./env/lib/python3.8/site-packages (from nbformat>=4.2.0->pycaret) (5.3.1)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.8/site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.8/site-packages (from requests>=2.27.1->pycaret) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./env/lib/python3.8/site-packages (from requests>=2.27.1->pycaret) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.8/site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: six in ./env/lib/python3.8/site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in ./env/lib/python3.8/site-packages (from numba>=0.55.0->pycaret) (0.40.1)
# Requirement already satisfied: matplotlib-inline in ./env/lib/python3.8/site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: stack-data in ./env/lib/python3.8/site-packages (from ipython>=5.5.0->pycaret) (0.6.2)
# Requirement already satisfied: pygments>=2.4.0 in ./env/lib/python3.8/site-packages (from ipython>=5.5.0->pycaret) (2.16.1)
# Requirement already satisfied: backcall in ./env/lib/python3.8/site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in ./env/lib/python3.8/site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: pickleshare in ./env/lib/python3.8/site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in ./env/lib/python3.8/site-packages (from ipython>=5.5.0->pycaret) (0.19.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in ./env/lib/python3.8/site-packages (from ipython>=5.5.0->pycaret) (4.8.0)
# Requirement already satisfied: typing-extensions; python_version < "3.10" in ./env/lib/python3.8/site-packages (from ipython>=5.5.0->pycaret) (4.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in ./env/lib/python3.8/site-packages (from ipython>=5.5.0->pycaret) (3.0.39)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in ./env/lib/python3.8/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (3.0.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in ./env/lib/python3.8/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (44.0.0)
# Requirement already satisfied: pytz>=2020.1 in ./env/lib/python3.8/site-packages (from pandas<2.0.0,>=1.3.0->pycaret) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in ./env/lib/python3.8/site-packages (from plotly>=5.0.0->pycaret) (8.2.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./env/lib/python3.8/site-packages (from imbalanced-learn>=0.8.1->pycaret) (3.2.0)
# Requirement already satisfied: zipp>=0.5 in ./env/lib/python3.8/site-packages (from importlib-metadata>=4.12.0->pycaret) (3.16.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in ./env/lib/python3.8/site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.9)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in ./env/lib/python3.8/site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.9)
# Requirement already satisfied: comm>=0.1.3 in ./env/lib/python3.8/site-packages (from ipywidgets>=7.6.5->pycaret) (0.1.4)
# Requirement already satisfied: wrapt<2,>=1.10 in ./env/lib/python3.8/site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.15.0)
# Requirement already satisfied: dash-html-components==2.0.0 in ./env/lib/python3.8/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: retrying in ./env/lib/python3.8/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in ./env/lib/python3.8/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.7)
# Requirement already satisfied: dash-core-components==2.0.0 in ./env/lib/python3.8/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: Werkzeug<2.3.0 in ./env/lib/python3.8/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Requirement already satisfied: dash-table==5.0.0 in ./env/lib/python3.8/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: ansi2html in ./env/lib/python3.8/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.8.0)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in ./env/lib/python3.8/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.5)
# Requirement already satisfied: attrs>=22.2.0 in ./env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (23.1.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10; python_version < "3.9" in ./env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in ./env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.30.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2023.7.1)
# Requirement already satisfied: rpds-py>=0.7.1 in ./env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.10.3)
# Requirement already satisfied: platformdirs>=2.5 in ./env/lib/python3.8/site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (3.10.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./env/lib/python3.8/site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.4.0)
# Requirement already satisfied: pure-eval in ./env/lib/python3.8/site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in ./env/lib/python3.8/site-packages (from stack-data->ipython>=5.5.0->pycaret) (1.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./env/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in ./env/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: wcwidth in ./env/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret) (0.2.6)
# Requirement already satisfied: click>=8.0 in ./env/lib/python3.8/site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.7)
# Requirement already satisfied: itsdangerous>=2.0 in ./env/lib/python3.8/site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing the libriaries

import pandas as pd
import numpy as np
from pycaret.regression import *
from sklearn.cluster import KMeans

# Load the dataset
df = pd.read_csv('Data_Sept1.csv')  # Updated file name

# Drop the specified columns
columns_to_drop = ['ID', 'Customer Pay']
df.drop(columns=columns_to_drop, inplace=True)

# Calculate the 'Custom_Miles' feature
#df['Customer RPM'] = df['Customer Pay'] / df['Miles']

# Drop rows with 'Customer Pay' equal to 0
#df = df[df[['Customer Pay', 'Customer RPM']] != 0]

# Drop duplicates
df.drop_duplicates(inplace=True)

# Handle missing values (drop rows with missing values)
df.dropna(inplace=True)

# Filter the data to keep only rows where 'Miles' < 50, but check if there are rows to filter first

#df = df[df['Miles'] > 50]

"""if df['Miles'].lt(50).any():
    df = df[df['Miles'] < 50]
else:
    print("No rows with 'Miles' less than 50 found in the dataset.")"""

# 4. Apply K-Means clustering to 'Miles' to create 'Miles_Cluster' (k=10)
miles_data = df[['Miles']]
kmeans = KMeans(n_clusters=10, random_state=0)
df['Miles_Cluster'] = kmeans.fit_predict(miles_data)


# 7. Calculate 'Miles_Range' based on custom ranges
custom_ranges = [0, 100, 200, 300, 400, 500, 600, 700, 800, 1000, 2000, 4000, 10000]
df['Miles_Range'] = pd.cut(df['Miles'], bins=custom_ranges, labels=False) + 1


# Convert 'Pickup Date' to datetime data type
df['Pickup Date'] = pd.to_datetime(df['Pickup Date'])

# Define the function to extract date features
def extract_date_features(df):
    df['Year'] = df['Pickup Date'].dt.year
    df['Month'] = df['Pickup Date'].dt.month
    df['Day'] = df['Pickup Date'].dt.day
    df['Dayofweek'] = df['Pickup Date'].dt.dayofweek
    df['DayOfyear'] = df['Pickup Date'].dt.dayofyear
    df['Week'] = df['Pickup Date'].dt.isocalendar().week
    df['Quarter'] = df['Pickup Date'].dt.quarter
    df['Is_month_start'] = df['Pickup Date'].dt.is_month_start
    df['Is_month_end'] = df['Pickup Date'].dt.is_month_end
    df['Is_quarter_start'] = df['Pickup Date'].dt.is_quarter_start
    df['Is_quarter_end'] = df['Pickup Date'].dt.is_quarter_end
    df['Is_year_start'] = df['Pickup Date'].dt.is_year_start
    df['Is_year_end'] = df['Pickup Date'].dt.is_year_end
    df['Semester'] = np.where(df['Quarter'].isin([1, 2]), 1, 2)
    df['Is_weekend'] = np.where(df['Dayofweek'].isin([5, 6]), 1, 0)
    df['Is_weekday'] = np.where(df['Dayofweek'].isin([0, 1, 2, 3, 4]), 1, 0)
    df['Days_in_month'] = df['Pickup Date'].dt.days_in_month
    return df

# Extract date features
df = extract_date_features(df)

# Create new features: LANE and LANE_KMA
df['LANE'] = df['Origin City'] + ', ' + df['Origin State'] + ' - ' + df['Delivery City'] + ', ' + df['Delivery State']

# Convert 'LANE_KMA' to categorical data type
#df['LANE'] = df['LANE'].astype('category')

# Combine 'Origin KMA' and 'Delivery KMA' into 'LANE_KMA' and treat it as categorical
df['LANE_KMA'] = df['Origin KMA'] + ' - ' + df['Delivery KMA']

# Convert 'LANE_KMA' to categorical data type
#df['LANE_KMA'] = df['LANE_KMA'].astype('category')

# Setup with the extracted date and new features
regression = setup(data=df,
                   target='RPM',
                   session_id=123,
                   normalize=True,
                   transformation=True,
                   train_size=0.80,
                   transformation_method='yeo-johnson')
                   #, remove_outliers=True) #,
                  # ignore_features=['Pickup Date']  # Exclude 'ID' and original 'Pickup Date' column
# Out:
# <style type="text/css">
# #T_446ac_row10_col1, #T_446ac_row16_col1, #T_446ac_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_446ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_446ac_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_446ac_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_446ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_446ac_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_446ac_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_446ac_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_446ac_row1_col1" class="data row1 col1" >RPM</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_446ac_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_446ac_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_446ac_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_446ac_row3_col1" class="data row3 col1" >(35344, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_446ac_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_446ac_row4_col1" class="data row4 col1" >(35344, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_446ac_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_446ac_row5_col1" class="data row5 col1" >(28275, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_446ac_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_446ac_row6_col1" class="data row6 col1" >(7069, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_446ac_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_446ac_row7_col1" class="data row7 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_446ac_row8_col0" class="data row8 col0" >Date features</td>
#       <td id="T_446ac_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_446ac_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_446ac_row9_col1" class="data row9 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_446ac_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_446ac_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_446ac_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_446ac_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_446ac_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_446ac_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_446ac_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_446ac_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_446ac_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_446ac_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_446ac_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_446ac_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_446ac_row16_col0" class="data row16 col0" >Transformation</td>
#       <td id="T_446ac_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_446ac_row17_col0" class="data row17 col0" >Transformation method</td>
#       <td id="T_446ac_row17_col1" class="data row17 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_446ac_row18_col0" class="data row18 col0" >Normalize</td>
#       <td id="T_446ac_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_446ac_row19_col0" class="data row19 col0" >Normalize method</td>
#       <td id="T_446ac_row19_col1" class="data row19 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_446ac_row20_col0" class="data row20 col0" >Fold Generator</td>
#       <td id="T_446ac_row20_col1" class="data row20 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_446ac_row21_col0" class="data row21 col0" >Fold Number</td>
#       <td id="T_446ac_row21_col1" class="data row21 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_446ac_row22_col0" class="data row22 col0" >CPU Jobs</td>
#       <td id="T_446ac_row22_col1" class="data row22 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_446ac_row23_col0" class="data row23 col0" >Use GPU</td>
#       <td id="T_446ac_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_446ac_row24_col0" class="data row24 col0" >Log Experiment</td>
#       <td id="T_446ac_row24_col1" class="data row24 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_446ac_row25_col0" class="data row25 col0" >Experiment Name</td>
#       <td id="T_446ac_row25_col1" class="data row25 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_446ac_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_446ac_row26_col0" class="data row26 col0" >USI</td>
#       <td id="T_446ac_row26_col1" class="data row26 col1" >53d3</td>
#     </tr>
#   </tbody>
# </table>

# %%
best=compare_models()

# %%
model=create_model(best)

# %%
final_model=finalize_model(model)

final_model

# %%
print(final_model)

# %%
# Saving the model

save_model(final_model, model_name='Main_Model_sept1')
